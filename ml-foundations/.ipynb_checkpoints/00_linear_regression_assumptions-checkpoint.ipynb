# %%
import pandas as pd

# %% [markdown]
# # Load data

# %% [markdown]
# ## Non-linear data

# %%
df = pd.read_csv("airfoil_self_noise.dat", sep="\t", names=['freq', 'angle', 'chord', 'vel', 'thick', 'lvl'])
display(df)
# Out:
#       freq  angle   chord   vel     thick      lvl
# 0      800    0.0  0.3048  71.3  0.002663  126.201
# 1     1000    0.0  0.3048  71.3  0.002663  125.201
# 2     1250    0.0  0.3048  71.3  0.002663  125.951
# 3     1600    0.0  0.3048  71.3  0.002663  127.591
# 4     2000    0.0  0.3048  71.3  0.002663  127.461
# ...    ...    ...     ...   ...       ...      ...
# 1498  2500   15.6  0.1016  39.6  0.052849  110.264
# 1499  3150   15.6  0.1016  39.6  0.052849  109.254
# 1500  4000   15.6  0.1016  39.6  0.052849  106.604
# 1501  5000   15.6  0.1016  39.6  0.052849  106.224
# 1502  6300   15.6  0.1016  39.6  0.052849  104.204
#
# [1503 rows x 6 columns]

# %%
X_cols = ['freq', 'angle', 'chord', 'vel', 'thick']
y_cols = 'lvl'
X = df[X_cols]
y = df[y_cols]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
r2_score(y, y_pred)
# Out:
# 0.5157097420928733

# %% [markdown]
# ## Linear data

# %%
from sklearn.datasets import make_regression

# %%
X_reg, y_reg = make_regression(n_samples=len(df), n_features=len(X_cols), noise=2, random_state=42)

# %%
df_reg = pd.DataFrame()
for idx in range(X_reg.shape[1]):
    df_reg[f"X_{idx}"] = X_reg[:,idx]
df_reg["y"] = y_reg

# %%
model = LinearRegression()
model.fit(X_reg, y_reg)
y_reg_pred = model.predict(X_reg)

# %%
r2_score(y_reg, y_reg_pred)
# Out:
# 0.9996666769168593

# %% [markdown]
# # Assumption checks

# %% [markdown]
# ## Linearity

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
for x in X_cols:
    df.plot.scatter(x=x, y='lvl')

# %%
df.corr()['lvl']
# Out:
# freq    -0.390711
# angle   -0.156108
# chord   -0.236162
# vel      0.125103
# thick   -0.312670
# lvl      1.000000
# Name: lvl, dtype: float64

# %%
for x in df_reg.columns:
    df_reg.plot.scatter(x=x, y='y')

# %%
df_reg.corr()['y']
# Out:
# X_0    0.464562
# X_1    0.415822
# X_2    0.627269
# X_3    0.259535
# X_4    0.338858
# y      1.000000
# Name: y, dtype: float64

# %% [markdown]
# ## Non correlated features

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df_reg.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Normally distributed errors

# %%
from statsmodels.stats.diagnostic import normal_ad

# %%
diff = abs(y) - abs(y_pred)

# %%
plt.hist(diff, bins=50)
plt.show()

# %%
normal_ad(diff)[1]
# Out:
# /home/data/anaconda3/lib/python3.7/site-packages/statsmodels/stats/_adnorm.py:66: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   S = np.sum((2*i[sl1]-1.0)/N*(np.log(z)+np.log(1-z[sl2])), axis=axis)
# 0.0013389588056109635

# %%
diff = abs(y_reg) - abs(y_reg_pred)

# %%
plt.hist(diff, bins=50)
plt.show()

# %%
normal_ad(diff)[1]
# Out:
# 0.9281748499278965

# %% [markdown]
# ## Non autocorrelated errors

# %%
from statsmodels.stats.stattools import durbin_watson

# %%
diff = abs(y) - abs(y_pred)

# %%
durbin_watson(diff)
# Out:
# 0.4474251031656881

# %%
plt.scatter(y, diff)
plt.show()

# %%
diff = abs(y_reg) - abs(y_reg_pred)

# %%
durbin_watson(diff)
# Out:
# 1.9170295707400036

# %%
plt.scatter(y, diff)
plt.show()

# %% [markdown]
# ## Homoscedastic errors

# %%
from statsmodels.stats.diagnostic import het_white
from scipy.stats import levene

# %%
diff = abs(y) - abs(y_pred)

# %%
levene(diff[:1000], diff[1000:])
# Out:
# LeveneResult(statistic=44.31840074291323, pvalue=3.902331097209928e-11)

# %%
plt.scatter(x=range(len(diff)), y=diff, alpha=0.5)

# %%
diff = abs(y_reg) - abs(y_reg_pred)

# %%
levene(diff[:1000], diff[1000:])
# Out:
# LeveneResult(statistic=0.899923369604956, pvalue=0.34295496418780014)

# %%
plt.scatter(x=range(len(diff)), y=diff, alpha=0.5)
